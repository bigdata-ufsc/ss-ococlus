# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# %matplotlib inline

# %% [markdown]
# ## Top 10 users

# %%
df_fs_top = pd.read_csv('fs_ny_t10_concat.csv', sep=";")
df_fs_top.head()
# Out:
#    new_tid                             lat_lon                  poi  \
# 0        0  40.9654169422336 -74.0628837642180               my bed
# 1        0  40.9653287788182 -74.0629239214116             nanas :)
# 2        0  40.9653550190346 -74.0628321335281  The Bush Hot Tub :)
# 3        0  40.9653379500000 -74.0628079000000         The Hang Out
# 4        0  40.9653558300157 -74.0628550805032     The Bush Hideout
#
#                root_type  label                 type      day  \
# 0         Nightlife Spot    185           Strip Club  Tuesday
# 1                   Food    185  American Restaurant  Tuesday
# 2  Outdoors & Recreation    185                 Pool  Tuesday
# 3         Nightlife Spot    185      Other Nightlife  Tuesday
# 4         Nightlife Spot    185            Speakeasy  Tuesday
#
#   time_discrete_label         time_bins weather  ...  \
# 0           afternoon  (1050.0, 1080.0]   Clear  ...
# 1               night  (1080.0, 1110.0]   Clear  ...
# 2               night  (1170.0, 1200.0]   Clear  ...
# 3               night  (1260.0, 1290.0]  Clouds  ...
# 4               night  (1290.0, 1320.0]  Clouds  ...
#
#    day|time_discrete_label|weather|rating  \
# 0            Tuesday|afternoon|Clear|-1.0
# 1                Tuesday|night|Clear|-1.0
# 2                Tuesday|night|Clear|-1.0
# 3               Tuesday|night|Clouds|-1.0
# 4               Tuesday|night|Clouds|-1.0
#
#            day|time_bins|weather|rating  \
# 0   Tuesday|(1050.0, 1080.0]|Clear|-1.0
# 1   Tuesday|(1080.0, 1110.0]|Clear|-1.0
# 2   Tuesday|(1170.0, 1200.0]|Clear|-1.0
# 3  Tuesday|(1260.0, 1290.0]|Clouds|-1.0
# 4  Tuesday|(1290.0, 1320.0]|Clouds|-1.0
#
#   time_discrete_label|time_bins|weather|rating  \
# 0        afternoon|(1050.0, 1080.0]|Clear|-1.0
# 1            night|(1080.0, 1110.0]|Clear|-1.0
# 2            night|(1170.0, 1200.0]|Clear|-1.0
# 3           night|(1260.0, 1290.0]|Clouds|-1.0
# 4           night|(1290.0, 1320.0]|Clouds|-1.0
#
#       type|day|time_discrete_label|time_bins|weather  \
# 0  Strip Club|Tuesday|afternoon|(1050.0, 1080.0]|...
# 1  American Restaurant|Tuesday|night|(1080.0, 111...
# 2          Pool|Tuesday|night|(1170.0, 1200.0]|Clear
# 3  Other Nightlife|Tuesday|night|(1260.0, 1290.0]...
# 4    Speakeasy|Tuesday|night|(1290.0, 1320.0]|Clouds
#
#        type|day|time_discrete_label|time_bins|rating  \
# 0  Strip Club|Tuesday|afternoon|(1050.0, 1080.0]|...
# 1  American Restaurant|Tuesday|night|(1080.0, 111...
# 2           Pool|Tuesday|night|(1170.0, 1200.0]|-1.0
# 3  Other Nightlife|Tuesday|night|(1260.0, 1290.0]...
# 4      Speakeasy|Tuesday|night|(1290.0, 1320.0]|-1.0
#
#     type|day|time_discrete_label|weather|rating  \
# 0       Strip Club|Tuesday|afternoon|Clear|-1.0
# 1  American Restaurant|Tuesday|night|Clear|-1.0
# 2                 Pool|Tuesday|night|Clear|-1.0
# 3     Other Nightlife|Tuesday|night|Clouds|-1.0
# 4           Speakeasy|Tuesday|night|Clouds|-1.0
#
#                    type|day|time_bins|weather|rating  \
# 0     Strip Club|Tuesday|(1050.0, 1080.0]|Clear|-1.0
# 1  American Restaurant|Tuesday|(1080.0, 1110.0]|C...
# 2           Pool|Tuesday|(1170.0, 1200.0]|Clear|-1.0
# 3  Other Nightlife|Tuesday|(1260.0, 1290.0]|Cloud...
# 4     Speakeasy|Tuesday|(1290.0, 1320.0]|Clouds|-1.0
#
#    type|time_discrete_label|time_bins|weather|rating  \
# 0   Strip Club|afternoon|(1050.0, 1080.0]|Clear|-1.0
# 1  American Restaurant|night|(1080.0, 1110.0]|Cle...
# 2             Pool|night|(1170.0, 1200.0]|Clear|-1.0
# 3  Other Nightlife|night|(1260.0, 1290.0]|Clouds|...
# 4       Speakeasy|night|(1290.0, 1320.0]|Clouds|-1.0
#
#   day|time_discrete_label|time_bins|weather|rating  \
# 0    Tuesday|afternoon|(1050.0, 1080.0]|Clear|-1.0
# 1        Tuesday|night|(1080.0, 1110.0]|Clear|-1.0
# 2        Tuesday|night|(1170.0, 1200.0]|Clear|-1.0
# 3       Tuesday|night|(1260.0, 1290.0]|Clouds|-1.0
# 4       Tuesday|night|(1290.0, 1320.0]|Clouds|-1.0
#
#   type|day|time_discrete_label|time_bins|weather|rating
# 0  Strip Club|Tuesday|afternoon|(1050.0, 1080.0]|...
# 1  American Restaurant|Tuesday|night|(1080.0, 111...
# 2     Pool|Tuesday|night|(1170.0, 1200.0]|Clear|-1.0
# 3  Other Nightlife|Tuesday|night|(1260.0, 1290.0]...
# 4  Speakeasy|Tuesday|night|(1290.0, 1320.0]|Cloud...
#
# [5 rows x 68 columns]

# %%
print(df_fs_top.groupby(['label']).nunique())
# Out:
#        new_tid  lat_lon  poi  root_type  label  type  day  \
# label
# 185         42      171  139          8      1    76    7
# 293         41      166  128          8      1    55    7
# 315         40      166  115          8      1    72    7
# 349         31      702  588         10      1   187    7
# 354         36      449  384          9      1   102    7
# 372         31      359  327         10      1   128    7
# 689         35       11    9          5      1     8    7
# 730         30       32   19          8      1    15    7
# 885         32       74   50          9      1    36    7
# 943         34      191  176          8      1   102    7
#
#        time_discrete_label  time_bins  weather  ...  \
# label                                           ...
# 185                      4         48        6  ...
# 293                      4         46        6  ...
# 315                      4         47        5  ...
# 349                      4         41        5  ...
# 354                      4         45        5  ...
# 372                      4         42        5  ...
# 689                      4         14        5  ...
# 730                      4         13        6  ...
# 885                      4         41        6  ...
# 943                      4         47        6  ...
#
#        day|time_discrete_label|weather|rating  day|time_bins|weather|rating  \
# label
# 185                                       265                           870
# 293                                       337                           744
# 315                                       261                           642
# 349                                       520                           829
# 354                                       430                           851
# 372                                       353                           491
# 689                                       137                           145
# 730                                       162                           194
# 885                                       176                           387
# 943                                       285                           501
#
#        time_discrete_label|time_bins|weather|rating  \
# label
# 185                                             355
# 293                                             381
# 315                                             322
# 349                                             624
# 354                                             498
# 372                                             390
# 689                                              46
# 730                                              71
# 885                                             195
# 943                                             330
#
#        type|day|time_discrete_label|time_bins|weather  \
# label
# 185                                              1670
# 293                                              1160
# 315                                              1299
# 349                                              1147
# 354                                              1150
# 372                                               511
# 689                                               145
# 730                                               198
# 885                                               520
# 943                                               545
#
#        type|day|time_discrete_label|time_bins|rating  \
# label
# 185                                             1515
# 293                                              890
# 315                                             1177
# 349                                             1135
# 354                                             1049
# 372                                              505
# 689                                               57
# 730                                              108
# 885                                              423
# 943                                              495
#
#        type|day|time_discrete_label|weather|rating  \
# label
# 185                                           1002
# 293                                            661
# 315                                            781
# 349                                           1046
# 354                                            751
# 372                                            483
# 689                                            137
# 730                                            180
# 885                                            305
# 943                                            399
#
#        type|day|time_bins|weather|rating  \
# label
# 185                                 1676
# 293                                 1180
# 315                                 1312
# 349                                 1171
# 354                                 1184
# 372                                  525
# 689                                  145
# 730                                  213
# 885                                  520
# 943                                  550
#
#        type|time_discrete_label|time_bins|weather|rating  \
# label
# 185                                                 1181
# 293                                                  702
# 315                                                  913
# 349                                                 1095
# 354                                                  840
# 372                                                  489
# 689                                                   46
# 730                                                   75
# 885                                                  315
# 943                                                  432
#
#        day|time_discrete_label|time_bins|weather|rating  \
# label
# 185                                                 878
# 293                                                 746
# 315                                                 642
# 349                                                 830
# 354                                                 854
# 372                                                 491
# 689                                                 145
# 730                                                 194
# 885                                                 387
# 943                                                 502
#
#        type|day|time_discrete_label|time_bins|weather|rating
# label
# 185                                                 1678
# 293                                                 1182
# 315                                                 1312
# 349                                                 1171
# 354                                                 1185
# 372                                                  525
# 689                                                  145
# 730                                                  213
# 885                                                  520
# 943                                                  551
#
# [10 rows x 68 columns]

# %%
print('Number of trajectories: ',df_fs_top['new_tid'].nunique())
print('Number of unique POIs: ',df_fs_top['poi'].nunique())
print('Number of unique POIs type: ',df_fs_top['type'].nunique())
print('Number of unique POIs root_type: ',df_fs_top['root_type'].nunique())
basic_stats(df_fs_top)
df_main_info(df_fs_top)
# Out:
# Number of trajectories:  352
# Number of unique POIs:  1741
# Number of unique POIs type:  310
# Number of unique POIs root_type:  10
#
# Basics:
# Number of users:  10
# Number of trajectories:  352
# AVG number of trajectories per user is 35.20 with STD of 4.44
# AVG trajectory length per user is 32.23 with STD of 15.46
#
# More stats:
# Number of users:  10
# Number of trajectories:  352
#
# Check-ins:
# Min number of check-ins in an user:  568
# Max number of check-ins in an user:  1952
# Number of average check-ins per user 1171.500 with std of 598.203.
# Number of unique POIs in the dataset:  310
#
# Trajectories:
# Min number of trajectories in an user:  30
# Max number of trajectories in an user:  42
# Number of average trajectories per user 35.200 with std of 4.442.

# %% [markdown]
# ### Create sequence file format

# %%
dimension = 'type|day|time_discrete_label' #e.g.: 'type', 'type|day', 'type|time_discrete_label', type|time_bins', 'type|day|time_discrete_label', 'type|day|time_discrete_label|time_bins', ...
file = "preprocessed/fs_ny_t10_concat_"+dimension.replace('|','-')+".dat"
create_sequence_file_data(df_fs_top, file, dimension)
# Out:
# Processando DataFrame: 100%|██████████████████████████████████████████████████| 11715/11715 [00:00<00:00, 53243.36it/s]
# Number of sequences:  352
# Process completed!

# %%
e = [10,14,18,15,17,15,13,15,12,16]
f = [110,120,125,115,130,115,120,115,125,120]
print(np.mean(e),np.std(e),np.var(e))
print(np.mean(f),np.std(f),np.var(f))
# Out:
# 14.5 2.247220505424423 5.05
# 119.5 5.678908345800274 32.25

# %% [markdown]
# ## Top 81 users

# %%
df_fs_81 = pd.read_csv('fs_ny_t81_concat.csv', sep=";")
print(df_fs_81['label'].nunique())
df_fs_81.head()
# Out:
# 81
#    new_tid                             lat_lon                         poi  \
# 0        0  40.7421883084845 -73.9879241890915         Madison Square Park
# 1        0  40.7421883084845 -73.9879241890915         Madison Square Park
# 2        0  40.7416730481413 -73.9742878438115  NYU Langone Medical Center
# 3        0  40.7421883084845 -73.9879241890915         Madison Square Park
# 4        0  40.7421883084845 -73.9879241890915         Madison Square Park
#
#                      root_type  label        day      type  rating weather  \
# 0        Outdoors & Recreation     14    Tuesday      Park     9.6   Clear
# 1        Outdoors & Recreation     14  Wednesday      Park     9.6  Clouds
# 2  Professional & Other Places     14  Wednesday  Hospital    -1.0   Clear
# 3        Outdoors & Recreation     14  Wednesday      Park     9.6   Clear
# 4        Outdoors & Recreation     14   Thursday      Park     9.6   Clear
#
#           time_bins  ...            time_bins|day|weather  \
# 0  (1110.0, 1140.0]  ...   (1110.0, 1140.0]|Tuesday|Clear
# 1    (420.0, 450.0]  ...  (420.0, 450.0]|Wednesday|Clouds
# 2    (570.0, 600.0]  ...   (570.0, 600.0]|Wednesday|Clear
# 3    (930.0, 960.0]  ...   (930.0, 960.0]|Wednesday|Clear
# 4    (420.0, 450.0]  ...    (420.0, 450.0]|Thursday|Clear
#
#             time_bins|day|rating    time_bins|weather|rating  \
# 0   (1110.0, 1140.0]|Tuesday|9.6  (1110.0, 1140.0]|Clear|9.6
# 1   (420.0, 450.0]|Wednesday|9.6   (420.0, 450.0]|Clouds|9.6
# 2  (570.0, 600.0]|Wednesday|-1.0   (570.0, 600.0]|Clear|-1.0
# 3   (930.0, 960.0]|Wednesday|9.6    (930.0, 960.0]|Clear|9.6
# 4    (420.0, 450.0]|Thursday|9.6    (420.0, 450.0]|Clear|9.6
#
#      day|weather|rating               type|time_bins|day|weather  \
# 0     Tuesday|Clear|9.6      Park|(1110.0, 1140.0]|Tuesday|Clear
# 1  Wednesday|Clouds|9.6     Park|(420.0, 450.0]|Wednesday|Clouds
# 2  Wednesday|Clear|-1.0  Hospital|(570.0, 600.0]|Wednesday|Clear
# 3   Wednesday|Clear|9.6      Park|(930.0, 960.0]|Wednesday|Clear
# 4    Thursday|Clear|9.6       Park|(420.0, 450.0]|Thursday|Clear
#
#                 type|time_bins|day|rating       type|time_bins|weather|rating  \
# 0       Park|(1110.0, 1140.0]|Tuesday|9.6     Park|(1110.0, 1140.0]|Clear|9.6
# 1       Park|(420.0, 450.0]|Wednesday|9.6      Park|(420.0, 450.0]|Clouds|9.6
# 2  Hospital|(570.0, 600.0]|Wednesday|-1.0  Hospital|(570.0, 600.0]|Clear|-1.0
# 3       Park|(930.0, 960.0]|Wednesday|9.6       Park|(930.0, 960.0]|Clear|9.6
# 4        Park|(420.0, 450.0]|Thursday|9.6       Park|(420.0, 450.0]|Clear|9.6
#
#          type|day|weather|rating         time_bins|day|weather|rating  \
# 0         Park|Tuesday|Clear|9.6   (1110.0, 1140.0]|Tuesday|Clear|9.6
# 1      Park|Wednesday|Clouds|9.6  (420.0, 450.0]|Wednesday|Clouds|9.6
# 2  Hospital|Wednesday|Clear|-1.0  (570.0, 600.0]|Wednesday|Clear|-1.0
# 3       Park|Wednesday|Clear|9.6   (930.0, 960.0]|Wednesday|Clear|9.6
# 4        Park|Thursday|Clear|9.6    (420.0, 450.0]|Thursday|Clear|9.6
#
#               type|time_bins|day|weather|rating
# 0       Park|(1110.0, 1140.0]|Tuesday|Clear|9.6
# 1      Park|(420.0, 450.0]|Wednesday|Clouds|9.6
# 2  Hospital|(570.0, 600.0]|Wednesday|Clear|-1.0
# 3       Park|(930.0, 960.0]|Wednesday|Clear|9.6
# 4        Park|(420.0, 450.0]|Thursday|Clear|9.6
#
# [5 rows x 36 columns]

# %%
# df_summary = create_df_map_traj_user(df_fs_81)

# %%
# print(df_summary.head())
# print(df_summary['User'].nunique())
# tmp = df_summary['User'].value_counts().to_dict()
# x = list(tmp.keys())
# y = list(tmp.values())
# top_81 = x[:81]

# %%
# df_fs_81 = df_fs_81[df_fs_81['label'].isin(top_81)]
# df_fs_81.reset_index(inplace=True,drop=True)
# # print(df_fs_81['label'].nunique())
# print(df_fs_81.head())

# %%
print('Number of trajectories: ',df_fs_81['new_tid'].nunique())
print('Number of unique POIs: ',df_fs_81['poi'].nunique())
print('Number of unique POIs type: ',df_fs_81['type'].nunique())
print('Number of unique POIs root_type: ',df_fs_81['root_type'].nunique())
basic_stats(df_fs_81)
df_main_info(df_fs_81)
# Out:
# Number of trajectories:  1749
# Number of unique POIs:  6324
# Number of unique POIs type:  437
# Number of unique POIs root_type:  10
#
# Basics:
# Number of users:  81
# Number of trajectories:  1749
# AVG number of trajectories per user is 21.59 with STD of 6.09
# AVG trajectory length per user is 22.81 with STD of 9.66
#
# More stats:
# Number of users:  81
# Number of trajectories:  1749
#
# Check-ins:
# Min number of check-ins in an user:  202
# Max number of check-ins in an user:  1952
# Number of average check-ins per user 515.901 with std of 365.313.
# Number of unique POIs in the dataset:  437
#
# Trajectories:
# Min number of trajectories in an user:  16
# Max number of trajectories in an user:  42
# Number of average trajectories per user 21.593 with std of 6.088.

# %%
dimension = 'type|time_bins' #e.g.: 'type', type|time_bins', 'type|day', 'type|time_bins|day', ...
file = "preprocessed/fs_ny_t81_concat_"+dimension.replace('|','-')+".dat"
create_sequence_file_data(df_fs_81, file, dimension)
# Out:
# Processando DataFrame: 100%|██████████████████████████████████████████████████| 41788/41788 [00:00<00:00, 47425.03it/s]
# Number of sequences:  1749
# Process completed!

# %% [markdown]
# ## Top 193 users

# %%
df_fs_193 = pd.read_csv('fs_ny_t193_concat.csv', sep=";")
print(df_fs_193['label'].nunique())
df_fs_193.head()
# Out:
# 193
#    new_tid                             lat_lon  \
# 0        0  40.8331652006224 -73.9418603427692
# 1        0  40.8340978041072 -73.9452672225881
# 2        0  40.8331652006224 -73.9418603427692
# 3        0  40.7646959283254 -73.8851974964414
# 4        0  40.7660790376824 -73.8835287094116
#
#                                     poi           root_type  label       day  \
# 0     The Lair Of Modern Strange Cowboy           Residence      6    Monday
# 1                   Galaxy Gourmet Deli                Food      6    Monday
# 2     The Lair Of Modern Strange Cowboy           Residence      6   Tuesday
# 3             Popeyes Louisiana Kitchen                Food      6  Thursday
# 4  MTA Bus Operations Depot - LaGuardia  Travel & Transport      6  Thursday
#
#                   type  rating weather         time_bins  ...  \
# 0       Home (private)    -1.0   Clear    (300.0, 330.0]  ...
# 1        Deli / Bodega     8.2  Clouds  (1380.0, 1410.0]  ...
# 2       Home (private)    -1.0  Clouds    (-0.001, 30.0]  ...
# 3  Fried Chicken Joint     6.6   Clear  (1050.0, 1080.0]  ...
# 4          Bus Station    -1.0   Clear  (1110.0, 1140.0]  ...
#
#              time_bins|day|weather            time_bins|day|rating  \
# 0      (300.0, 330.0]|Monday|Clear      (300.0, 330.0]|Monday|-1.0
# 1   (1380.0, 1410.0]|Monday|Clouds     (1380.0, 1410.0]|Monday|8.2
# 2    (-0.001, 30.0]|Tuesday|Clouds     (-0.001, 30.0]|Tuesday|-1.0
# 3  (1050.0, 1080.0]|Thursday|Clear   (1050.0, 1080.0]|Thursday|6.6
# 4  (1110.0, 1140.0]|Thursday|Clear  (1110.0, 1140.0]|Thursday|-1.0
#
#       time_bins|weather|rating   day|weather|rating  \
# 0    (300.0, 330.0]|Clear|-1.0    Monday|Clear|-1.0
# 1  (1380.0, 1410.0]|Clouds|8.2    Monday|Clouds|8.2
# 2   (-0.001, 30.0]|Clouds|-1.0  Tuesday|Clouds|-1.0
# 3   (1050.0, 1080.0]|Clear|6.6   Thursday|Clear|6.6
# 4  (1110.0, 1140.0]|Clear|-1.0  Thursday|Clear|-1.0
#
#                           type|time_bins|day|weather  \
# 0         Home (private)|(300.0, 330.0]|Monday|Clear
# 1       Deli / Bodega|(1380.0, 1410.0]|Monday|Clouds
# 2       Home (private)|(-0.001, 30.0]|Tuesday|Clouds
# 3  Fried Chicken Joint|(1050.0, 1080.0]|Thursday|...
# 4        Bus Station|(1110.0, 1140.0]|Thursday|Clear
#
#                            type|time_bins|day|rating  \
# 0          Home (private)|(300.0, 330.0]|Monday|-1.0
# 1          Deli / Bodega|(1380.0, 1410.0]|Monday|8.2
# 2         Home (private)|(-0.001, 30.0]|Tuesday|-1.0
# 3  Fried Chicken Joint|(1050.0, 1080.0]|Thursday|6.6
# 4         Bus Station|(1110.0, 1140.0]|Thursday|-1.0
#
#                     type|time_bins|weather|rating  \
# 0        Home (private)|(300.0, 330.0]|Clear|-1.0
# 1       Deli / Bodega|(1380.0, 1410.0]|Clouds|8.2
# 2       Home (private)|(-0.001, 30.0]|Clouds|-1.0
# 3  Fried Chicken Joint|(1050.0, 1080.0]|Clear|6.6
# 4         Bus Station|(1110.0, 1140.0]|Clear|-1.0
#
#                   type|day|weather|rating  \
# 0        Home (private)|Monday|Clear|-1.0
# 1         Deli / Bodega|Monday|Clouds|8.2
# 2      Home (private)|Tuesday|Clouds|-1.0
# 3  Fried Chicken Joint|Thursday|Clear|6.6
# 4         Bus Station|Thursday|Clear|-1.0
#
#            time_bins|day|weather|rating  \
# 0      (300.0, 330.0]|Monday|Clear|-1.0
# 1    (1380.0, 1410.0]|Monday|Clouds|8.2
# 2    (-0.001, 30.0]|Tuesday|Clouds|-1.0
# 3   (1050.0, 1080.0]|Thursday|Clear|6.6
# 4  (1110.0, 1140.0]|Thursday|Clear|-1.0
#
#                    type|time_bins|day|weather|rating
# 0    Home (private)|(300.0, 330.0]|Monday|Clear|-1.0
# 1   Deli / Bodega|(1380.0, 1410.0]|Monday|Clouds|8.2
# 2  Home (private)|(-0.001, 30.0]|Tuesday|Clouds|-1.0
# 3  Fried Chicken Joint|(1050.0, 1080.0]|Thursday|...
# 4   Bus Station|(1110.0, 1140.0]|Thursday|Clear|-1.0
#
# [5 rows x 36 columns]

# %%
df_summary = create_df_map_traj_user(df_fs_193)

# %%
print('Number of trajectories: ',df_fs_193['new_tid'].nunique())
print('Number of unique POIs: ',df_fs_193['poi'].nunique())
print('Number of unique POIs type: ',df_fs_193['type'].nunique())
print('Number of unique POIs root_type: ',df_fs_193['root_type'].nunique())
basic_stats(df_fs_193)
df_main_info(df_fs_193)
# Out:
# Number of trajectories:  3079
# Number of unique POIs:  10808
# Number of unique POIs type:  491
# Number of unique POIs root_type:  10
#
# Basics:
# Number of users:  193
# Number of trajectories:  3079
# AVG number of trajectories per user is 15.95 with STD of 6.33
# AVG trajectory length per user is 20.52 with STD of 8.06
#
# More stats:
# Number of users:  193
# Number of trajectories:  3079
#
# Check-ins:
# Min number of check-ins in an user:  127
# Max number of check-ins in an user:  1952
# Number of average check-ins per user 346.870 with std of 284.283.
# Number of unique POIs in the dataset:  491
#
# Trajectories:
# Min number of trajectories in an user:  10
# Max number of trajectories in an user:  42
# Number of average trajectories per user 15.953 with std of 6.334.

# %%
dimension = 'type|day' #e.g.: 'type', 'type|day', type|time_bins', 'type|time_bins|day', ...
file = "preprocessed/fs_ny_t193_concat_"+dimension.replace('|','-')+".dat"
create_sequence_file_data(df_fs_193, file, dimension)
# Out:
# Processando DataFrame: 100%|██████████████████████████████████████████████████| 66946/66946 [00:01<00:00, 52407.84it/s]
# Number of sequences:  3079
# Process completed!

# %% [markdown]
# # tests

# %%
new_df_fs_yw = df_foursquare_yw.drop(columns=['checkin_id','venue_id','tid','lat_lon','split_year_week','time','rating',
                                             'price','day','weather','poi','root_type'])
print(new_df_fs_yw.head())
a = new_df_fs_yw.groupby(['label','new_tid'])
print(a.first())
# print(a.nunique()[0:20])
# print(a.nunique()[0:20].groupby('label').sum())
print(a.nunique())
# print(a.get_group(1)['new_tid'].nunique)
b = new_df_fs_yw.groupby(['label'])
b.nunique()
# Out:
#    new_tid                     type  label
# 0        0       Seafood Restaurant      1
# 1        0  New American Restaurant      1
# 2        0    General Entertainment      1
# 3        0      American Restaurant      1
# 4        1      American Restaurant      1
#                                type
# label new_tid
# 1     0          Seafood Restaurant
#       1         American Restaurant
#       2              Sandwich Place
#       3                 Coffee Shop
#       4                   Gift Shop
# ...                             ...
# 1083  30504                  Office
#       30505                 Gay Bar
#       30506                Bus Line
#       30507    Gym / Fitness Center
#       30508                  Office
#
# [30511 rows x 1 columns]
#                type
# label new_tid
# 1     0           4
#       1          12
#       2          13
#       3           3
#       4           3
# ...             ...
# 1083  30504       1
#       30505       4
#       30506       6
#       30507       2
#       30508       1
#
# [30511 rows x 1 columns]
#        new_tid  type  label
# label
# 1           18    46      1
# 2           24    63      1
# 3           27    55      1
# 4           39    49      1
# 5           19    25      1
# ...        ...   ...    ...
# 1079        21    34      1
# 1080        19    45      1
# 1081        10    29      1
# 1082        10    25      1
# 1083        40    63      1
#
# [1083 rows x 3 columns]

# %% [markdown]
# # support methods

# %%
def create_sequence_file_data(df,pfile,dim):
    sequence = []
    past_tid = None
    curr_tid = None
    num_of_seqs = 0
#     f = open("data/real_application/foursquare_NY/fs_ny_week_sequences.dat", "w")
    f = open(pfile, "w")
    
    for i in tqdm(range(int(len(df))), colour='blue', desc='Processando DataFrame'):
        curr_tid = df.loc[i,"new_tid"]
        index = df.index[df.loc[i,"new_tid"]]
        
        if index == 0:
            sequence.append(str(df.loc[i,dim].replace(' ','_')))
            past_tid = curr_tid
        elif curr_tid == past_tid:
            sequence.append(str(df.loc[i,dim].replace(' ','_')))
        elif curr_tid != past_tid:
            tmp = ' '.join(sequence)
            tmp += '\n'
            f.write(tmp)
            num_of_seqs += 1
            sequence = []
            sequence.append(str(df.loc[i,dim].replace(' ','_')))
            past_tid = curr_tid
        
        if i == (len(df)-1):
            tmp = ' '.join(sequence)
            f.write(tmp)
            num_of_seqs += 1
            
    f.close()
    
#     for index, row in df.iterrows():
#         curr_tid = row["new_tid"]
            
#         if index == 0:
#             sequence.append(str(row["type"].replace(' ','_')))
#             past_tid = curr_tid
#         elif curr_tid == past_tid:
#             sequence.append(str(row["type"].replace(' ','_')))
#         elif curr_tid != past_tid:
#             tmp = ' '.join(sequence)
#             tmp += '\n'
#             f.write(tmp)
#             sequence = []
#             sequence.append(str(row["type"].replace(' ','_')))
#             past_tid = curr_tid
            
#     f.close()
    print('Number of sequences: ',num_of_seqs)
    print("Process completed!")

# %%
# basic_stats(df_fs_top)

# %%
def basic_stats(df):
    print('\nBasics:')
    num_of_users = df['label'].nunique()
    num_of_trajs = df['new_tid'].nunique()
    avg_trajs_per_user = df.groupby(['label']).nunique()['new_tid'].mean()
    std_trajs_per_user = df.groupby(['label']).nunique()['new_tid'].std()
    tmp = df.groupby(['label','new_tid'])
    avg_traj_len_per_user = tmp.count()['type'].groupby('label').mean().mean()
    std_traj_len_per_user = tmp.count()['type'].groupby('label').std().mean()
    
    
    print('Number of users: ',num_of_users)
    print('Number of trajectories: ',num_of_trajs)
    print('AVG number of trajectories per user is {:.2f} with STD of {:.2f}'.format(avg_trajs_per_user,std_trajs_per_user))
    print('AVG trajectory length per user is {:.2f} with STD of {:.2f}'.format(avg_traj_len_per_user,std_traj_len_per_user))

# %%
def df_main_info(df):
    print('\nMore stats:')
    print('Number of users: ',df['label'].nunique())
    print('Number of trajectories: ',df['new_tid'].nunique())
    
    print('\nCheck-ins:')
    # print(df_foursquare.groupby('label')['new_tid'].count())
    print('Min number of check-ins in an user: ',df.groupby('label')['new_tid'].count().min())
    print('Max number of check-ins in an user: ',df.groupby('label')['new_tid'].count().max())
    print('Number of average check-ins per user {:.3f} with std of {:.3f}.'.format(df.groupby('label')['new_tid'].count().mean(),
                                                                                   df.groupby('label')['new_tid'].count().std()))
    print('Number of unique POIs in the dataset: ',df['type'].nunique())

    print('\nTrajectories:')
    # print(df_foursquare.groupby('label')['new_tid'].nunique())
    print('Min number of trajectories in an user: ',df.groupby('label')['new_tid'].nunique().min())
    print('Max number of trajectories in an user: ',df.groupby('label')['new_tid'].nunique().max())
    print('Number of average trajectories per user {:.3f} with std of {:.3f}.'.format(df.groupby('label')['new_tid'].nunique().mean(),
                                                                                   df.groupby('label')['new_tid'].nunique().std()))

    # df_foursquare
    # print(df_foursquare[df_foursquare['label'==1]])
    # df_foursquare

# %%
# def create_df_map_traj_user(df):
def create_df_map_traj_user(df=pd.DataFrame):
    '''
    Method to support the calculation of the quality result.
    It returns a dataframe with the users and their trajectories with its respective length.
    '''
    try:
        #     df = pd.read_csv('data/real_application/foursquare_NY/fs_ny_top_users_10.csv', sep=";")
        df_map_traj_user = pd.DataFrame(columns=['Tid','Traj_length','User'])
        tids = []
        user = ''
        traj_length = 0

        sequence = []
        past_tid = None
        curr_tid = None
        num_of_seqs = 0
        map_element_id = 0
        unique_elements = {}
        map_id_to_element = {}

        for i in range(len(df)):
            curr_tid = df.loc[i,"new_tid"]
            if curr_tid not in tids:
                tids.append(int(curr_tid))
                user = int(df.loc[i,"label"])
                traj_length = len(df[df['new_tid'] == curr_tid])
                # append rows to an empty DataFrame
                df_map_traj_user = df_map_traj_user.append({'Tid' : curr_tid, 'Traj_length' : traj_length, 'User' : user},ignore_index = True)
        df_map_traj_user['Tid'] = df_map_traj_user['Tid'].astype(int, errors='ignore')
        df_map_traj_user['Traj_length'] = df_map_traj_user['Traj_length'].astype(int, errors='ignore')
        df_map_traj_user['User'] = df_map_traj_user['User'].astype(int, errors='ignore')

    #     print(df_map_traj_user.shape)
    #     print(df_map_traj_user.head())
    #     print('Todo DataFrame (traj_length):',' mean=',df_map_traj_user['Traj_length'].mean(),
    #           ' std=',df_map_traj_user['Traj_length'].std())
    #     u_185 = df_map_traj_user[df_map_traj_user['User']==185]
    #     print(u_185)
    #     print('User 185:',' mean=',u_185['Traj_length'].mean(),' std=',u_185['Traj_length'].std())
    #     df_map_traj_user.groupby(['label']).nunique()['new_tid'].mean()
        r = (df_map_traj_user.groupby(['User'])['Traj_length']
             .agg([np.count_nonzero,np.mean,np.std])
             .rename(columns={'count_nonzero':'Count_trajs',
                              'mean':'AVG_traj_length',
                              'std':'STD_traj_length'}))
    #     print('Número médio de trajs por usuário = {:.2f} com DP = {:.2f}'.format(r['Count_trajs'].mean(),
    #                                                                        r['Count_trajs'].std()))
    #     print('Tamanho médio das trajs por usuário = {:.2f} com DP médio = {:.2f}'.format(r['AVG_traj_length'].mean(),
    #                                                                        r['STD_traj_length'].mean()))
        return df_map_traj_user
    except:
        raise('Please, check the input data format.')
        return None
